# %% [markdown]
# ## Web Scraping Demo
# This is a simple demonstration of web scraping using Python. The code uses libraries such as `requests` and `BeautifulSoup` to extract job data from websites like Wuzzuf and Bayt.

# %% [markdown]
# ### Step 1: Install Required Libraries
# Install the `lxml` library for HTML parsing.

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\ahmed\appdata\local\programs\python\python312\lib\site-packages (5.3.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Step 2: Import Required Libraries
# Import the necessary libraries for making HTTP requests and parsing HTML.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Step 3: Scrape Wuzzuf for Job Data
# Define the target URL and fetch the page content.

# %%
# Define the URL for Wuzzuf search page
u = "https://wuzzuf.net/search/jobs?a=spbg&q=machine%20learning"

# Send a GET request to the URL
page = requests.get(u)

# Parse the page content using BeautifulSoup
soup = BeautifulSoup(page.content, "html.parser")

# %% [markdown]
# #### Step 3.1: Extract Job Titles
# Use BeautifulSoup to find and print all job titles on the page.

# %%
# Find all job titles on the page
j_t = soup.find_all('h2', class_="css-m604qf")
for i in j_t:
    print(i.text)
# Out:
# Machine Learning Manager
# AI Engineer
# Robotics and Programming Engineer
# Sales Specialist
# Senior Backend Developer in Node/Express
# Machinist / Mechanical Engineer
# AI Technical Team Lead (Computer Vision Focus & NLP)
# Senior ML JD
# Online Coding Instructor
# Senior Full Stack/ Embedded Engineering
# Senior AI Engineer
# Senior Full Stack Developer (MERN or Laravel Stack)
# Technical sales and marketing manager
# Process Electronics Engineer
# Electrical Maintenance Engineer (Fresh Grads)

# %% [markdown]
# #### Step 3.2: Extract Job Locations
# Extract and print the locations of the jobs.

# %%
# Find all job locations
loc = soup.find_all("span", class_="css-5wys0k")
for i in loc:
    print(i.text)
# Out:
# Cairo, Egypt
# Heliopolis, Cairo, Egypt
# Alexandria, Egypt
# Downtown, Cairo, Egypt
# Manchester, United Kingdom
# Larnaca, Cyprus
# Sheikh Zayed, Giza, Egypt
# Damietta, Egypt
# Riyadh, Saudi Arabia
# Riyadh, Saudi Arabia
# Cairo, Egypt
# Cairo, Egypt
# Hadayek Alahram, Giza, Egypt
# 10th of Ramadan City, Sharqia, Egypt
# 10th of Ramadan City, Sharqia, Egypt

# %% [markdown]
# #### Step 3.3: Extract Company Names
# Extract and print the company names associated with the jobs.

# %%
# Find all company names
company = soup.find_all("a", class_="css-17s97q8")
for i in company:
    print(i.text)
# Out:
# kcsc -
# Integrated Technology Group -
# Smart Technology -
# Gila Electric -
# Give Brite  -
# kpec international -
# Lumin -
# ysolution -
# Confidential -
# Qudra Tech -
# RMG -
#  Si-Vision -
# Etkaan -
# VIVO -
# Bakeland Egypt  -

# %% [markdown]
# #### Step 3.4: Extract Job Post Dates
# Extract and print when the jobs were posted.

# %%
# Find all job posting dates
# <div class="css-do6t5g">1 month ago</div>
# <div class="css-4c4ojb">5 hours ago</div>
dates = soup.find_all("div", class_= ["css-do6t5g", "css-4c4ojb"])
for i in dates:
    print(i.text)
# Out:
# 1 month ago
# 4 days ago
# 17 days ago
# 3 days ago
# 2 months ago
# 1 month ago
# 20 days ago
# 10 days ago
# 2 months ago
# 6 days ago
# 1 month ago
# 11 days ago
# 11 days ago
# 18 days ago
# 3 days ago

# %% [markdown]
# #### Step 3.5: Extract Job Types
# Extract and print the types of jobs (e.g., Full-time, Part-time).

# %%
# Find all job types
# <span class="css-1ve4b75 eoyjyou0">Full Time</span>
job_type = soup.find_all("span", class_="css-1ve4b75 eoyjyou0")
for i in job_type:
    print(i.text)
# Out:
# Full Time
# Full Time
# Full Time
# Full Time
# Full Time
# Full Time
# Full Time
# Full Time
# Full Time
# Part Time
# Full Time
# Full Time
# Full Time
# Full Time
# Full Time
# Full Time

# %% [markdown]
# #### Step 3.6: Extract Job URLs
# Extract and print the URLs for individual job postings.

# %%
# Extract job URLs
# <h2 class="css-m604qf">
# <a href="https://wuzzuf.net/jobs/p/ow9y8zcxQbne-Machine-Learning-Manager-kcsc-Cairo-Egypt" target="_blank" rel="noreferrer" class="css-o171kl">Machine Learning Manager</a></h2>
jobs_url = []
urls = soup.find_all("h2", class_="css-m604qf")
for i in urls:
    jobs_url.append(i.find('a').attrs["href"])
jobs_url
# Out:
# ['https://wuzzuf.net/jobs/p/ow9y8zcxQbne-Machine-Learning-Manager-kcsc-Cairo-Egypt',
#  'https://wuzzuf.net/jobs/p/mJweLehwNSbz-AI-Engineer-Integrated-Technology-Group-Cairo-Egypt',
#  'https://wuzzuf.net/jobs/p/jjEycNgftu1U-Robotics-and-Programming-Engineer-Smart-Technology-Alexandria-Egypt',
#  'https://wuzzuf.net/jobs/p/PfXPkSfnCCNs-Sales-Specialist-Gila-Electric-Cairo-Egypt',
#  'https://wuzzuf.net/jobs/p/3k4DYwP9VAza-Senior-Backend-Developer-in-NodeExpress-Give-Brite-Manchester-United-Kingdom',
#  'https://wuzzuf.net/jobs/p/eRVXqix8zgJQ-Machinist-Mechanical-Engineer-kpec-international-Larnaca-Cyprus',
#  'https://wuzzuf.net/jobs/p/1kRUuVPxsf8W-AI-Technical-Team-Lead-Computer-Vision-Focus-NLP-Lumin-Giza-Egypt',
#  'https://wuzzuf.net/jobs/p/iitM79Aq3BJp-Senior-ML-JD-ysolution-Damietta-Egypt',
#  'https://wuzzuf.net/jobs/p/Ej8oiMp2sfqj-Online-Coding-Instructor-Riyadh-Saudi-Arabia',
#  'https://wuzzuf.net/jobs/p/lewDJYtw0FhS-Senior-Full-Stack-Embedded-Engineering-Qudra-Tech-Riyadh-Saudi-Arabia',
#  'https://wuzzuf.net/jobs/p/YqALuLpVSgcA-Senior-AI-Engineer-RMG-Cairo-Egypt',
#  'https://wuzzuf.net/jobs/p/YhxFt5TgYjpF-Senior-Full-Stack-Developer-MERN-or-Laravel-Stack-Si-Vision-Cairo-Egypt',
#  'https://wuzzuf.net/jobs/p/sRnWBoAEpms2-Technical-sales-and-marketing-manager-Etkaan-Giza-Egypt',
#  'https://wuzzuf.net/jobs/p/41ZtIDJmT23i-Process-Electronics-Engineer-VIVO-Sharqia-Egypt',
#  'https://wuzzuf.net/jobs/p/7iLBi1OwvnFX-Electrical-Maintenance-Engineer-Fresh-Grads-Bakeland-Egypt-Sharqia-Egypt']

# %%
for url in jobs_url[0:3]:
    url = url.replace(" ", "")
    print(url)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    print(soup.title.text)
# Out:
# https://wuzzuf.net/jobs/p/ow9y8zcxQbne-Machine-Learning-Manager-kcsc-Cairo-Egypt
# Machine Learning Manager Job at kcsc in Cairo, Egypt – Apply Now!
# https://wuzzuf.net/jobs/p/mJweLehwNSbz-AI-Engineer-Integrated-Technology-Group-Cairo-Egypt
# AI Engineer Job at Integrated Technology Group in Heliopolis, Cairo – Apply Now!
# https://wuzzuf.net/jobs/p/jjEycNgftu1U-Robotics-and-Programming-Engineer-Smart-Technology-Alexandria-Egypt
# Robotics and Programming Engineer Job at Smart Technology in Alexandria, Egypt – Apply Now!

# %% [markdown]
# #### Step 3.7: Fetch Individual Job Details
# Fetch and print the titles of individual jobs from their URLs.

# %%
# Example URL for testing
# url = "https://wuzzuf.net/jobs/p/5NFxSMKMH5K0-SeniorMid-Senior-Deep-Learning-Engineer-Cairo-Egypt?o=1&l=sp&t=sj&a=machine%20learning|search-v3|spbg"
import requests
from bs4 import BeautifulSoup

url = "https://www.bayt.com/en/egypt/jobs/data-science-jobs/"

# Send a GET request and parse the content
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
print(soup.title.text)
# Out:
# Data Science Jobs in Egypt (2024) - Bayt.com

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <link href="https://secure.b8cdn.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"/>
# <link href="https://cdn-cookieyes.com/" rel="preconnect"/>
# <link href="https://secure.b8cdn.com" rel="dns-prefetch"/>
# <link href="https://fonts.gstatic.com/" rel="dns-prefetch"/>
# <link href="https://cdn-cookieyes.com/" rel="dns-prefetch"/>
# <link href="https://log.cookieyes.com/" rel="dns-prefetch"/>
# <link href="https://directory.cookieyes.com/" rel="dns-prefetch"/>
# <meta content="data science jobs in egypt, data science vacancies egypt, data science career opportunities in egypt" name="keywords"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Bayt.com FZ-LLC" name="copyright"/>
# <meta content="strict-origin-when-cross-origin" name="referrer"/>
# <meta content="116830345011417" data-js-id="meta-fb_app_id" property="fb:app_id"/>
# <meta content="Bayt.com" data-js-id="meta-og_site_name" property="og:site_name"/>
# <meta content="Data Science Jobs in Egypt  (2024) - Bayt.com" data-js-id="meta-og_title" property="og:title"/>
# <meta content="https://secure.b8cdn.com/images/logos/fb_bayt_new_en.png" data-js-id="meta-og_image_secure_url" property="og:image:secure_url"/>
# <meta content="http://secure.b8cdn.com/images/logos/fb_bayt_new_en.png" data-js-id="meta-og_image" property="og:image"/>
# <meta content="Apply now to over 300 Data Science jobs in Egypt and make your job hunting simpler. Find the latest Data Science job vacancies and employment opportunities in Egypt." data-js-id="meta-og_description" property="og:description"/>
# <meta content="Apply now to over 300 Data Science jobs in Egypt and make your job hunting simpler. Find the latest Data Science job vacancies and employment opportunities in Egypt." data-js-id="meta-description" name="description"/>
# <meta content="https://www.bayt.com/en/egypt/jobs/data-science-jobs/" data-js-id="meta-og_url" property="og:url"/>
# <meta content="summary" data-js-id="meta-twitter_card" name="twitter:card"/>
# <meta content="@Baytcom" data-js-id="meta-twitter_site" name="twitter:site"/>
# <link data-js-id="link-next" href="https://www.bayt.com/en/egypt/jobs/data-science-jobs/?page=2" rel="next"/>
# <link href="/push-notifications/app/manifest.json" rel="manifest"/>
# <link href="//secure.b8cdn.com/bayt/assets/b8static/favicon/js/favicon.ico" rel="icon" sizes="any"/>
# <link href="//secure.b8cdn.com/bayt/assets/b8static/favicon/js/favicon.svg" rel="icon" type="image/svg+xml"/>
# <link href="//secure.b8cdn.com/bayt/assets/b8static/favicon/js/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link data-js-id="link-canonical" href="https://www.bayt.com/en/egypt/jobs/data-science-jobs/" rel="canonical"/>
# <link data-js-id="link-x-default" href="https://www.bayt.com/en/egypt/jobs/data-science-jobs/" hreflang="x-default" rel="alternate"/>
# <link data-js-id="link-en" href="https://www.bayt.com/en/egypt/jobs/data-science-jobs/" hreflang="en" rel="alternate"/>
# <link data-js-id="link-ar" href="https://www.bayt.com/ar/egypt/jobs/data-science-jobs/" hreflang="ar" rel="alternate"/>
# <style>@media only screen and (min-width:1025px){#jsMainClusterContainer .u-scrolly{max-height:calc(-170px + 100vh)}#jsMiniJobView .u-scrolly{max-height:calc(-325px + 100vh)}}</style>
# <style>
# /*<![CDATA[*/
# @media screen{.print-only{display:none!important}}@media screen and (min-width:1024px){.search-bar:not(.is-active).is-compact>.input-pack,.search-bar:not(.is-active)>.b-close,.search-bar:not(.is-compact)>.b-search{display:none}}.has-icon{position:relative}.has-icon>.icon{position:absolute;top:50%;right:12px;margin:auto;transform:translateY(-50%)}.has-icon.to-left>.icon{right:auto;left:10px}.popover{display:none}.icon{min-width:18px}.slider{position:relative}.slider-arrow{color:transparent}.slider-arrows{position:absolute}.t-danger{color:#ff3b30}.h3,h1,h2,h4,h6{line-height:1.2;margin:0 0 .5em;color:#000}.list.is-basic,.list.is-basic>li{padding-left:0}.accordion-toggle:checked+.accordion-title,.btn,.btn.is-large,.btn.is-small,.btn.is-xsmall,.t-bold{font-weight:700}.popover,nav>.nav{text-align:left}.dropdown,.list.is-basic,.media-list,.nav{list-style:none}.btn,.input,.msg-actions,.nav>li>a>.icon,.pagination>li,input.switch+label{vertical-align:middle}.accordion-title,.dropdown>li>a,.pagination>li>a,a{text-decoration:none}.btn,.dropdown>li>a,.label,.msg-actions,.nav>li>a,.t-nowrap{white-space:nowrap}*,:after,:before{box-sizing:inherit}html{box-sizing:border-box;font-family:Lato,"Noto Kufi Arabic",sans-serif;font-size:16px;line-height:1.67;scroll-behavior:smooth}body,html{padding:0;margin:0;background:#f4f4f4;color:#3b3b3b}a{color:#2784fc}button,input,select{font-family:inherit}h1{font-size:2.875rem}h2{font-size:2.25rem}.h3{font-size:1.75rem}.dlist,.list{font-size:16px}.dlist,.list>li{line-height:1.625}h4{font-size:1.5rem}h6{font-size:1rem}.list{padding-left:1em}.box,.col{padding:10px}.list>li{padding-left:1.375em;font-size:1em}.list.is-basic.is-spaced>li{padding:6px 0}.list.is-basic.is-spaced.is-compact>li{padding:0 0 8px}.accordion,.accordion-title,.nav.is-aux.is-small>li>a{font-size:14px}.box{max-width:1000px;margin:0 auto}.box.is-wide{max-width:1440px}.row{display:flex;flex-flow:row wrap;flex:1 0 auto}.row.is-compact>.col{flex-grow:0;padding:3px}.row.h-align-left{justify-content:flex-start}.row.h-align-center{justify-content:center}.row.h-align-between{justify-content:space-between}.row.v-align-center{align-items:center}.col{display:block;flex:1 1 auto}.popover,.toggler-active>:last-child,.toggler-inactive>:first-child{display:none}.col.is-2{flex:0 0 auto;width:16.66667%}.col.is-4{flex:0 0 auto;width:33.33333%}.is-attached{position:absolute;z-index:1}.is-attached.to-screen{position:fixed;height:auto;z-index:5000}.dropdown>li,.has-icon,.sticky-sense{position:relative}.sticky-sidebar{will-change:min-height}.popover{position:absolute;min-width:270px;background-color:#fff;border:1px solid #e7e9ed;border-radius:5px;z-index:10010;overflow:visible;outline:0}.popover-owner{position:relative;overflow:visible}.accordion-animate,.btn,.media-list>li>div{overflow:hidden}.toggle-head{padding:15px 20px;z-index:0}.accordion{border-bottom:1px solid #e7e9ed}.accordion-toggle,input.switch{position:absolute;width:.01px;height:.01px;opacity:0;overflow:hidden;z-index:-1}.nav,nav{z-index:10010}.accordion-toggle:checked+.accordion-title+.accordion-animate{max-height:1000px;opacity:1}.accordion-toggle:checked+.accordion-title:after{transform:translateY(-50%) rotate(180deg)}.accordion-toggle+.accordion-title:after{content:"\E804";position:absolute;top:50%;right:20px;color:#b9bfcb;transform-origin:50%;transform:translateY(-50%)}.accordion-title{position:relative;display:block;padding:5px 20px;margin:0;border-top:1px solid #e7e9ed;color:#3b3b3b}.btn,.dropdown,.input{font-size:.875rem}.accordion-content,.dropdown>li>a{padding:10px 20px;position:relative}.accordion-animate{max-height:0;opacity:.5}.accordion-animate>.accordion-content{display:block}.accordion-content{display:none;border-top:1px solid #e7e9ed}.btn,div.btn{display:inline-block}.btn{line-height:1;padding:11px;background-color:#2784fc;color:#fff;border-radius:4px;text-align:center;border:1px solid #2784fc}.dropdown>li>a,.t-medium{font-weight:400}.dropdown,.searchable,.select,div.btn{overflow:vis ...
# /*]]>*/
# </style>
# <script>!function(n){var a=[],e=setInterval(function(){if(B8.v){for(var n;n=a.pop();)B8.ready(n);clearInterval(e)}},100);n.B8=n.B8||{ready:function(n){a.push(n)}}}(window);B8v={"domainType":"jobs","cookiesDomain":".bayt.com","devProjects":{"generic":0,"yiiBetaAndDev":0,"baytUIProfile":1,"jsMicroCvBuilder":1,"newVueJS":1,"freemium_project":true},"pageCached":true,"saveNav":false,"amplitudeApiKey":"6e362603a9c35b5505d9ce2047990487","jsCdnRoot":"\/\/secure.b8cdn.com","B8trkUrl":"https:\/\/trk.bayt.com","ssdcookie":"SSD0","userDataCookie":"UADCN","isShagheelUrl":false,"adsenseCSA":{"pageOptions":{"channel":6339614250,"query":"Data Science Jobs in Egypt","hl":"en","adPage":1,"adtest":"off","styleId":"3741995929"}},"firebase":{"files":[{"id":485836676,"file":"https:\/\/www.gstatic.com\/firebasejs\/7.8.1\/firebase-app.js"},{"id":3440100177,"file":"https:\/\/www.gstatic.com\/firebasejs\/7.8.1\/firebase-messaging.js"}],"config":{"firebaseConfig":{"apiKey":"AIzaSyB0mE5ok6flEiUrp-I8ENZ0wjbbjatP1kM","authDomain":"bayt-com-api-project-690072141335.firebaseapp.com","databaseURL":"https:\/\/bayt-com-api-project-690072141335.firebaseio.com","projectId":"bayt.com:api-project-690072141335","storageBucket":"undefined","messagingSenderId":"690072141335","appId":"1:690072141335:web:b54325063687927189e652","measurementId":"G-C2STKV07BY"},"publicVapidKey":"BHNvLdnKk5ozRNy9C-FpKjWIlHrInxRsh9IaAwYEKvYyFRQblbduZCZg5ffn56wibWFgGwQm2zcosg-c1ZR09hI"},"notifScript":{"id":1182710737,"file":"\/bayt\/assets\/baytui-791jrceb\/js\/webPushNotifications.js"}},"globalSearchVars":{"page":0,"jobAlertScript":"https:\/\/secure.b8cdn.com\/bayt\/assets\/userregistration-2j1x57aj\/js\/registerJobAlert.js","showJA":true,"clickedFacet":""},"deleteAllMessage":"<h5>Confirm unsaving your Saved Jobs<\/h5><p>This action will remove all jobs in your Saved Jobs list. Are you sure you want to continue?<\/p>","deleteAllMessageOk":"OK","deleteAllMessageCancel":"Cancel","showPopupAfterJobAlert":false,"csrf":{"token":"b8a7f55fe8767b82340bc7cfc0f04fe6272ab86d"},"cdn":{"CdnDomain":"\/\/secure.b8cdn.com","HttpsCdnDomain":"https:\/\/secure.b8cdn.com","cssCdnRoot":"\/\/secure.b8cdn.com","imagesCdnRoot":"\/\/secure.b8cdn.com\/images","jsCdnRoot":"\/\/secure.b8cdn.com","HttpsEmailCdn":"https:\/\/secure.b8cdn.com"},"comon":{"sessionToken":"Browser:4085417022981318850,0,0,0,SJ1L5G,0,1,255c4927a1bf4bf1eefcdb16ad1c026c&21,YB0LUH,,&4085417021555770211"},"jsLoad":{"gsiClient":true},"view":{"userConfirmationScript":"https:\/\/secure.b8cdn.com\/bayt\/assets\/userconfirmation-3yrqpsph\/js\/userConfirmationBaytUI.js","registerJobAlertScript":"https:\/\/secure.b8cdn.com\/bayt\/assets\/userregistration-2j1x57aj\/js\/registerJobAlert.js","fromJobSearch":"\/en\/egypt\/jobs\/data-science-jobs\/","confirmDeleteMsg":"This application will be deleted. Are you sure you want to continue?","bttnCloseText":"Close","emptyEmailAddress":"No email address provided","invalidEmailAddress":"Email address is invalid","resendConfirmEmailMssg":"Confirm your email address to start applying to jobs","resendConfirmationButton":"Resend Confirmation Email","usedEmailAddress":"Email address is already used","goBackBtn":"Go Back","okText":"OK","cancelText":"Cancel","savedLink":"<i class='icon is-star'><\/i>Saved","shareWithYourFriends":"Share with Your Friends","applyLocalText1":"This job is for locals only","jobAlertRegisterParamsOfUrl":"{&quot;p&quot;:[&quot;eg&quot;],&quot;v&quot;:&quot;data science&quot;}","dynamicUrl":"https:\/\/bayt.page.link\/open-in-app"},"searchHistory":[],"searchSlugs":[{"countryInUrl":"algeria"},{"countryInUrl":"bahrain"},{"countryInUrl":"bahrain","cityInUrl":"manama"},{"countryInUrl":"egypt"},{"countryInUrl":"egypt","cityInUrl":"alexandria"},{"countryInUrl":"egypt","cityInUrl":"cairo"},{"countryInUrl":"india"},{"countryInUrl":"iraq"},{"countryInUrl":"iraq","cityInUrl":"baghdad"},{"countryInUrl":"jordan"},{"countryInUrl":"jordan","cityInUrl":"amman"},{"countryInUrl":"kuwait"},{"countryInUrl":"kuwait"," ...
# <title data-js-id="meta-title">Data Science Jobs in Egypt (2024) - Bayt.com</title>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# </head>
# <body class="fixed-nav"><script defer="defer" id="2516446433" src="https://secure.b8cdn.com/bayt/assets/baytui-791jrceb/js/eventsDataCollector.js"></script>
# <div class="no-print" data-auto_prompt="true" data-auto_select="false" data-cancel_on_tap_outside="false" data-client_id="690072141335.apps.googleusercontent.com" data-close_on_tap_outside="false" data-context="use" data-current_query_string="" data-itp_support="true" data-login_uri="https://www.bayt.com/ajax/user-login/user-login/one-tap-login/" data-referrer_url="en/egypt/jobs/data-science-jobs" data-use_fedcm_for_prompt="true" id="g_id_onload">
# </div>
# <nav data-bayt-scrolllock="8" data-scrolllock='{"unblock":"ul.nav.is-active,.no-capture-right,.list-menu-group"}' id="baytNav">
# <ul class="nav" data-nav='{"autoHide":false}' id="navList" style="align-items:center">
# <li class="m" data-bars="">
# <a aria-label="Menu" class="is-toggle" href="#"><i class="icon is-bars m0"></i></a>
# </li>
# <li class="is-wide-m">
# <a class="is-logo u-iblock" href="https://www.bayt.com/" id="baytLogo">
# <img alt="Bayt.com" class="" height="35" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%2026.19%205.56'%3E%3Cpath%20fill='%23fff'%20fill-rule='evenodd'%20d='M11.97%204.8c-.25%200-.45-.23-.45-.52%200-.3.2-.5.45-.5h2.87v.4a.6.6%200%200%201-.58.62zm2.29-3.56h-3.48v.77h3.48c.33-.01.6.26.58.62V3h-2.87c-.66%200-1.19.56-1.2%201.27.01.7.54%201.28%201.2%201.28h2.29c.74%200%201.32-.63%201.33-1.39V2.63c-.01-.77-.59-1.4-1.33-1.39zm5.9%200h.74v2.91c-.01.78-.6%201.4-1.35%201.4h-3.4V4.8h3.4c.33%200%20.6-.3.6-.65V3.8h-2.67c-.74%200-1.33-.64-1.33-1.42V1.24h.75v1.13c-.01.35.25.64.57.64h2.69zM6.73%204.8c-.32%200-.58-.28-.59-.63v-.39h2.9c.24%200%20.44.2.43.5%200%20.29-.19.52-.43.52zm-.59-1.79V1.24H5.4v2.93c0%20.76.6%201.39%201.33%201.39h2.31c.65%200%201.18-.58%201.17-1.28%200-.7-.52-1.28-1.17-1.27zm20.05%200v.78H22.2v.36c-.01.36.27.65.6.65h3.38v.76H22.8c-.74%200-1.33-.63-1.34-1.4V1.23h.74v1.77z'/%3E%3Cpath%20fill='%23ffd42a'%20fill-rule='evenodd'%20d='M0%201.8%202.39.54l2.38%201.24v-.55L2.4%200%200%201.24Z'/%3E%3C/svg%3E" width="99"/>
# </a>
# </li>
# <li class="m">
# <a class="btn is-round is-inverse is-xsmall" href="https://bayt.page.link/nav" id="navUseAppBtn" rel="nofollow">
# USE APP	</a>
# </li>
# <li class="is-wide-d">
# <ul class="nav is-main can-toggle" data-capture="" data-toggle-bars="" id="yw0">
# <li><a href="https://www.bayt.com/en/egypt/">Home</a></li>
# <li class="popover-owner has-pointer has-inline is-selected" data-popover=""><a href="https://www.bayt.com/en/egypt/jobs/search/">Find Jobs</a>
# <ul class="popover is-inline dropdown p0y-m t-small-d t-regular-m in-nav" data-placement="bl">
# <li><a href="https://www.bayt.com/en/egypt/jobs/search/">Find Jobs</a></li>
# <li class="is-title t-mute"><span>Browse Jobs</span></li>
# <li><a href="https://www.bayt.com/en/egypt/jobs/sectors/" rel="nofollow">Jobs by Sector</a></li>
# <li><a href="https://www.bayt.com/en/jobs/locations/">Jobs by Location</a></li>
# <li class="d"><a href="https://www.bayt.com/en/egypt/companies/">Jobs by Companies</a></li>
# <li><a href="https://www.bayt.com/en/egypt/jobs/executive-level-jobs/">Executive Jobs<span class="u-right"><i class="icon is-tie"></i></span></a></li>
# <li><a href="https://www.bayt.com/en/egypt/jobs/work-from-home/">Work from Home Jobs</a></li>
# <li><a href="https://www.bayt.com/en/egypt/salaries/">Salaries</a></li>
# </ul>
# </li>
# <li class="d"><a href="https://www.bayt.com/en/register-j/?native_source=CreateYourCV">Create Your CV</a></li>
# <li class="popover-owner has-pointer has-inline" data-popover=""><a href="https://www.bayt.com/en/blog/">Blog</a>
# <ul class="popover is-inline dropdown p0y-m t-small-d t-regular-m in-nav" data-placement="bl">
# <li><a href="https://www.bayt.com/en/blog/category/job-search-tips-1489187/">Job Search Tips</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/the-powerful-cv-1489194/">The Powerful CV</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/interviews-and-offers-1489195/">Interviews and Offers</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/grow-your-career-1489197/">Grow Your Career</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/market-knowledge-1739/">Market Knowledge</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/employer-corner-1418873/">Employer Corner</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/press-releases-12828/">Press Releases</a></li>
# </ul>
# </li>
# <li class="popover-owner has-pointer has-inline" data-popover=""><a href="https://www.bayt.com/en/cv-writing/?native_source=CVW-top-menu">CV Services</a>
# <ul class="popover is-inline dropdown p0y-m t-small-d t-regular-m in-nav" data-placement="bl">
# <li><a href="https://www.bayt.com/en/cv-writing/?native_source=CVW-top-menu">Professional CV Writing</a></li>
# <li class="has-divider p10x d"><a class="btn is-success t-small" href="https://www.bayt.com/en/premium/?native_source=nav"><span class="t-inverse"><i class="icon is-crown"></i> Upgrade to Premium</span></a></li>
# </ul>
# </li>
# <li class="popover-owner has-pointer has-inline" data-more="" data-popover="" style="display:none;"><a href="#">More</a>
# <div class="popover is-inline" data-bayt-popover="4" data-placement="bl">
# <ul class="dropdown p0-m t-small-d t-regular-m in-nav"></ul>
# </div></li>
# <li class="is-wide-d"><span></span></li>
# <li class="is-group">
# <ul class="list is-inline is-basic is-spaced t-nowrap">
# <li><a class="btn is-small is-inverse u-expanded-m" href="https://www.bayt.com/en/login/">Log In</a></li>
# <li class="d"><a class="btn is-small is-inverse is-outline u-expanded-m d" href="https://www.bayt.com/en/register-j/">Register</a></li>
# <li class="m"><a class="btn is-small is-outline u-expanded-m m" href="https://www.bayt.com/en/register-j/">Register</a></li>
# <li class="d"><a class="btn is-small is-inverse is-outline u-expanded-m d" href="https://www.bayt.com/en/employers/">For Employers</a></li>
# </ul>
# </li>
# <li class="is-first">
# <ul class="nav is-aux">
# <li class="is-wide-m m"><a aria-label="Close" class="b-close" data-nav-close="" href="#"></a></li>
# <li class="popover-owner" data-popover='{"relocate":true, "trigger":"click"}'><a aria-label="Apps" href="#"><i class="icon is-apps"></i> </a><div class="popover is-pointing is-full" data-placement="br">
# <div class="list-menu">
# <div class="list-menu-title">
# <a class="b-close is-large t-mute u-abs m" data-popover-close="" href="#"></a>
# <h6 class="t-center-m m0"> Products By Bayt.com </h6>
# </div>
# <div class="list-menu-group t-center" data-empty="Nothing up to now!">
# <div class="row is-m dark-links">
# <a class="col is-4" href="https://www.bayt.com">
# <img alt="Bayt.com" class="img-apps is-b" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Bayt.com</div>
# </a>
# <a class="col is-4" href="https://shagheel.bayt.com/">
# <img alt="Shagheel" class="img-apps is-shagheel" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Shagheel</div>
# </a>
# <a class="col is-4" href="https://specialties.bayt.com/">
# <img alt="Specialities" class="img-apps is-specialties" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Specialities</div>
# </a>
# <a class="col is-4" href="https://www.bayt.com/en/courses/learning-home/">
# <img alt="Learning" class="img-apps is-learning" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Learning</div>
# </a>
# <a class="col is-4" href="https://www.bayt.com/en/company/">
# <img alt="Companies" class="img-apps is-companies" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Companies</div>
# </a>
# <a class="col is-4" href="https://www.bayt.com/en/egypt/salaries/">
# <img alt="Salaries" class="img-apps is-salaries" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Salaries</div>
# </a>
# <a class="col is-4" href="https://people.bayt.com/">
# <img alt="People" class="img-apps is-people" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">People</div>
# </a>
# <a class="col is-4" href="https://www.bayt.com/en/blog/">
# <img alt="Blog" class="img-apps is-blog" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Blog</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li><span></span></li>
# <li>
# <ul class="nav is-aux is-small">
# <li><a data-js-tolang="ar" href="/ar/egypt/jobs/data-science-jobs/" id="en-language" onclick="BaytNavigation.changeLanguage(this, 0); return false;">العربية</a></li>
# </ul>
# </li>
# <li class="m"><section class="m t-center m10t bg-inverse jsMobilePromotions u-none">
# <div class="card">
# <div class="card-head p10t">
# <i class="t-primary icon is-smartphone is-48 m0"></i>
# <h4 class="m10y">Use Our Mobile App </h4>
# </div>
# <div class="card-content">
# <p class="m0">Get contacted by recruiters directly with our newest chat feature!</p>
# </div>
# <div class="card-foot">
# <a class="btn m20b u-expanded-m" href="https://bayt.page.link/m-menu">Download Now</a>
# </div>
# </div>
# </section>
# </li>
# </ul> </li>
# <li class="m p10">
# </li>
# </ul>
# </nav>
# <div class="t-center print-only p10t"><img alt="Bayt.com" loading="lazy" src="//secure.b8cdn.com/bayt/assets/b8static/svg/bayt-logo.svg"/></div>
# <section class="bg-inverse-d">
# <div class="box p20-d">
# <form action="https://www.bayt.com/en/jobs/" class="search-bar" data-action="~/" id="form" method="get" onsubmit="event.preventDefault(); submitSearch(this);">
# <div class="row is-compact is-m">
# <div class="col is-5-d is-12-m">
# <div class="searchable has-icon to-left">
# <input aria-label="keyword" autocomplete="off" class="input is-large p20l-m" data-searchable='
# 					{
# 						"view": {
# 							"render": "searchControl.renderItem",
# 							"highlight": true,
# 							"placement": "bl",
# 							"placeholder":"Start your search by typing into the search box above",
# 							"autoActivate":false
# 						},
# 						"on":{
# 							"close": "searchControl.selectItem"
# 						},
# 						"data": {
# 							"format":"searchControl.getValue",
# 							"static": false,
# 							"fetch": "searchControl.autoComplete",
# 							"delay": 400,
# 							"text" : "title",
# 							"value": "id",
# 							"group": "group",
# 							"search": "*",
# 							"history":true
# 						}
# 					}
# 					' id="text_search" name="keyword" placeholder="Search jobs, skills, companies" type="text" value="data science"/>
# <i class="icon is-search d"></i> <input aria-label="search" name="composite_search" type="hidden" value="1"/>
# </div>
# </div>
# <div class="col is-5-d is-10-m">
# <div class="select has-icon to-left">
# <select aria-label="select country" class="input is-large spec-con-input" data-searchable='{"data":{"group":"group" , "selected":"egypt"},"view":{"name":"$1"}, "optional":false}' data-value="egypt" id="search_country" name="country">
# <option disabled="" value="non">Select location</option>
# <option selected="" value="international">All locations</option>
# <option value="algeria">Algeria</option>
# <option value="bahrain">Bahrain</option>
# <option value="manama">Bahrain - Manama</option>
# <option selected="" value="egypt">Egypt</option>
# <option value="alexandria">Egypt - Alexandria</option>
# <option value="cairo">Egypt - Cairo</option>
# <option value="india">India</option>
# <option value="iraq">Iraq</option>
# <option value="baghdad">Iraq - Baghdad</option>
# <option value="jordan">Jordan</option>
# <option value="amman">Jordan - Amman</option>
# <option value="kuwait">Kuwait</option>
# <option value="al-kuwait">Kuwait - Al Kuwait</option>
# <option value="lebanon">Lebanon</option>
# <option value="beirut">Lebanon - Beirut</option>
# <option value="libya">Libya</option>
# <option value="morocco">Morocco</option>
# <option value="casablanca">Morocco - Casablanca</option>
# <option value="oman">Oman</option>
# <option value="muscat">Oman - Muscat</option>
# <option value="pakistan">Pakistan</option>
# <option value="qatar">Qatar</option>
# <option value="doha">Qatar - Doha</option>
# <option value="saudi-arabia">Saudi Arabia</option>
# <option value="dammam">Saudi Arabia - Dammam</option>
# <option value="eastern-province">Saudi Arabia - Eastern Province</option>
# <option value="jeddah">Saudi Arabia - Jeddah</option>
# <option value="jubail">Saudi Arabia - Jubail</option>
# <option value="khobar">Saudi Arabia - Khobar</option>
# <option value="mecca">Saudi Arabia - Mecca</option>
# <option value="medina">Saudi Arabia - Medina</option>
# <option value="riyadh">Saudi Arabia - Riyadh</option>
# <option value="sri-lanka">Sri Lanka</option>
# <option value="tunisia">Tunisia</option>
# <option value="tunis">Tunisia - Tunis</option>
# <option value="uae">United Arab Emirates</option>
# <option value="abu-dhabi">United Arab Emirates - Abu Dhabi</option>
# <option value="ajman">United Arab Emirates - Ajman</option>
# <option value="al-ain">United Arab Emirates - Al Ain</option>
# <option value="dubai">United Arab Emirates - Dubai</option>
# <option value="fujairah">United Arab Emirates - Fujairah</option>
# <option value="ras-al-khaimah">United Arab Emirates - Ras Al Khaimah</option>
# <option value="sharjah">United Arab Emirates - Sharjah</option>
# <option value="yemen">Yemen</option>
# </select>
# <i class="icon is-location"></i>
# </div>
# </div>
# <div class="col is-2">
# <button class="btn is-large u-expanded" data-js-aid="search" id="submitButtonQuickSearchWidget" type="submit">
# <i class="icon is-search m0 m"></i><span class="d">Find Jobs</span> </button>
# </div>
# </div>
# </form> </div>
# </section>
# <div id="popTemp"></div>
# <section class="box is-wide row is-reversed-d is-collapsed-m no-wrap">
# <div class="col is-9-d is-half sticky-sense u-none" id="jsMiniJobView">
# <div id="formToggleSheet">
# <div class="sticky-content" id="view_inner">
# </div>
# <div class="u-none" id="toggleFooter"></div>
# </div>
# </div>
# <div class="col is-9-d sticky-sense" id="jsMainListingContainer">
# <div class="sticky-sidebar" data-sticky-sidebar="">
# <div class="sticky-content" id="results_inner">
# <!-- Job Results-->
# <div class="card u-shadow">
# <div class="card-head">
# <h1 class="h3" data-automation-id="heading1">Data Science Jobs in Egypt</h1>
# <div class="row v-align-center-d h-align-between">
# <b class="m20b-m" data-automation-id="XJobsFound">
# 301 jobs found	</b>
# <div class="row is-m h-align-between-m h-align-right-d">
# <a class="btn m" href="#" id="filter">
# Filter	</a>
# <div class="popover-owner u-iblock" data-popover='{"trigger":"click"}'>
# <div class="btn is-clear p0x">
# <span class="t-medium" data-automation-id="id_sort_jobs">
# Sort by: <b>Relevance</b><i class="icon is-arrow-down m0 m5l"></i>
# </span>
# </div>
# <div class="popover" data-placement="br">
# <ul class="dropdown">
# <li>
# <a data-automation-id="id_sort_jobs_relevance" href="/en/egypt/jobs/data-science-jobs/?options%5Bsort%5D%5B%5D=r" rel="nofollow">
# Relevance	</a>
# </li>
# <li class="has-divider">
# <a data-automation-id="id_sort_jobs_date" href="/en/egypt/jobs/data-science-jobs/?options%5Bsort%5D%5B%5D=d" rel="nofollow">
# Date	</a>
# </li>
# <li class="has-divider">
# <a data-automation-id="id_sort_jobs_language" href="/en/egypt/jobs/data-science-jobs/?options%5Bsort%5D%5B%5D=l" rel="nofollow">
# Language	</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card-content" id="results_inner_card">
# <ul class="media-list in-card is-spaced is-divided is-reversed has-hover-d has-rects has-free-img bb" data-empty="Nothing available">
# <li class="to-screen is-inner u-shade-m p0 bg-inverse" id="mobile-job-alert">
# <div class="row is-m no-wrap v-align-center p0y-d p10y-m p10x bg-lite">
# <div class="col u-expanded t-large t-bold p10l">
# <span class="">Create a job alert for similar positions</span>
# </div>
# <div class="col t-right p0">
# <input class="switch is-small" id="jobAlertSwitch" onclick="showRegisterJobAlertPopup(false , '1');" type="checkbox"/><label for="jobAlertSwitch"></label>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="5206515" data-js-job="">
# <div class="row is-compact is-m no-wrap">
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# <a data-automation-is_aggregated="0" data-automation-is_external="0" data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/senior-presales-solution-architect-quot-data-quot-5206515/">
# Senior Presales Solution Architect " Data " </a>
# </h2>
# <div class="col p10l t-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="5206515" data-js-jobheartstatus="" data-savelinklatter="5206515" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon is-heart-solid is-20 m0 t-danger"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# </div>
# <div class="row is-m no-wrap">
# <img alt="GIZA Systems logo" class="jb-logo b bg-inverse u-block" height="50" onerror="this.onerror=null;this.src='//secure.b8cdn.com/bayt/assets/jobs-cwg3nimv/images/no-logo.svg';" src="//secure.b8cdn.com/48x48/images/logo/31/1835431_logo_1711893255_n.png" title="GIZA Systems" width="50"/>
# <div class="t-nowrap p10l">
# <div class="t-nowrap"><span class="t-default t-small" data-trim='{"lines":2,"text":""}'>GIZA Systems </span></div>
# <div class="t-mute t-small">Cairo · Egypt</div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# <b>Data Science</b> Solution Arch plays a crucial role in helping businesses adopt <b>data</b> ... client needs and demonstrate how <b>data science</b> solutions can solve businessproblems. Key ...</div>
# <div class="jb-tags m10t">
# <dl class="dlist is-spaced t-small m0y row">
# <dt class="p0 m20r jb-label-careerlevel"><i class="icon is-briefcase m5r"></i> Mid Career<span class="t-small t-mute"> · </span>10-15 Years of Experience</dt>
# </dl>
# </div>
# <div class="jb-footer row is-m v-align-center m10t">
# <div class="jb-date col p0x p0t t-mute">
# <span class="p0x t-small m10r t-bold t-mute" data-automation-id="job-active-date" data-automation-jobactivedate="1730037155" data-automation-ty="1" id="jb-date-5206515">
# 30+ days ago </span>
# </div>
# </div> </li>
# <li class="has-pointer-d" data-job-id="5214512" data-js-job="">
# <div class="row is-compact is-m no-wrap">
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# <a data-automation-is_aggregated="0" data-automation-is_external="1" data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/immdiate-hiring-for-product-managerfor-a-factory-in-egypt-5214512/">
# immdiate hiring for product managerfor a factory in Egypt </a>
# </h2>
# <div class="col p10l t-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="5214512" data-js-jobheartstatus="" data-savelinklatter="5214512" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon is-heart-solid is-20 m0 t-danger"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# </div>
# <div class="row is-m no-wrap">
# <img alt="Shaheen Farouk logo" class="jb-logo b bg-inverse u-block" height="50" src="//secure.b8cdn.com/bayt/assets/jobs-cwg3nimv/images/no-logo.svg" title="Shaheen Farouk" width="50"/>
# <div class="t-nowrap p10l">
# <div class="t-nowrap"><span class="t-default t-small" data-trim='{"lines":2,"text":""}'>Shaheen Farouk </span></div>
# <div class="t-mute t-small">Alexandria · Egypt</div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# This is a full-time on-site role for an enthusiactic, active and full of energy Senior Product Manager for a small factory for producing…</div>
# <div class="jb-tags m10t">
# <dl class="dlist is-spaced t-small m0y row">
# <dt class="p0 m20r jb-label-careerlevel"><i class="icon is-briefcase m5r"></i> Management<span class="t-small t-mute"> · </span>5-10 Years of Experience</dt>
# </dl>
# </div>
# <div class="jb-footer row is-m v-align-center m10t">
# <div class="jb-date col p0x p0t t-mute">
# <span class="p0x t-small m10r t-bold t-mute" data-automation-id="job-active-date" data-automation-jobactivedate="1732295918" data-automation-ty="1" id="jb-date-5214512">
# 8 days ago </span>
# </div>
# <div class="jb-easy-apply col p0x p0t t-right">
# <a class="btn is-small" data-js-skip="" href="/en/register-j/applicant-register/?jb_id=5214512&amp;from_job_search=%252Fen%252Fegypt%252Fjobs%252Fdata-science-jobs%252F&amp;BtnView=1" rel="nofollow">
# <i class="icon is-flash2 m5r"></i>Easy Apply </a>
# </div>
# </div> </li>
# <li class="has-pointer-d" data-job-id="5201473" data-js-job="">
# <div class="row is-compact is-m no-wrap">
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# <a data-automation-is_aggregated="0" data-automation-is_external="1" data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/power-bi-developer-5201473/">
# Power BI Developer </a>
# </h2>
# <div class="col p10l t-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="5201473" data-js-jobheartstatus="" data-savelinklatter="5201473" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon is-heart-solid is-20 m0 t-danger"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# </div>
# <div class="row is-m no-wrap">
# <img alt="Flint Consulting Ltd logo" class="jb-logo b bg-inverse u-block" height="50" onerror="this.onerror=null;this.src='//secure.b8cdn.com/bayt/assets/jobs-cwg3nimv/images/no-logo.svg';" src="//secure.b8cdn.com/48x48/images/logo/76/1678376_logo_1487754409_n.png" title="Flint Consulting Ltd" width="50"/>
# <div class="t-nowrap p10l">
# <div class="t-nowrap"><span class="t-default t-small" data-trim='{"lines":2,"text":""}'>Flint Consulting Ltd </span></div>
# <div class="t-mute t-small">Cairo · Egypt</div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# , dashboards, and <b>data</b> visualizations.• Strong understanding of <b>data</b> modeling, <b>data</b> warehousing, and ETL ... Ability to integrate various <b>data</b> sources and maintain <b>data</b>...</div>
# <div class="jb-tags m10t">
# <dl class="dlist is-spaced t-small m0y row">
# <dt class="p0 m20r jb-label-careerlevel"><i class="icon is-briefcase m5r"></i> 2-12 Years of Experience</dt>
# </dl>
# </div>
# <div class="jb-footer row is-m v-align-center m10t">
# <div class="jb-date col p0x p0t t-mute">
# <span class="p0x t-small m10r t-bold t-mute" data-automation-id="job-active-date" data-automation-jobactivedate="1728756407" data-automation-ty="1" id="jb-date-5201473">
# 30+ days ago </span>
# </div>
# <div class="jb-easy-apply col p0x p0t t-right">
# <a class="btn is-small" data-js-skip="" href="/en/register-j/applicant-register/?jb_id=5201473&amp;from_job_search=%252Fen%252Fegypt%252Fjobs%252Fdata-science-jobs%252F&amp;BtnView=1" rel="nofollow">
# <i class="icon is-flash2 m5r"></i>Easy Apply </a>
# </div>
# </div> </li>
# <li class="has-pointer-d" data-job-id="5199788" data-js-job="">
# <div class="row is-compact is-m no-wrap">
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# <a data-automation-is_aggregated="0" data-automation-is_external="1" data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/microsoft-crm-administrator-5199788/">
# Microsoft CRM Administrator </a>
# </h2>
# <div class="col p10l t-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="5199788" data-js-jobheartstatus="" data-savelinklatter="5199788" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon is-heart-solid is-20 m0 t-danger"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# </div>
# <div class="row is-m no-wrap">
# <img alt="VeriPark Gulf logo" class="jb-logo b bg-inverse u-block" height="50" onerror="this.onerror=null;this.src='//secure.b8cdn.com/bayt/assets/jobs-cwg3nimv/images/no-logo.svg';" src="//secure.b8cdn.com/48x48/images/logo/62/1487162_logo_1464262638_n.png" title="VeriPark Gulf" width="50"/>
# <div class="t-nowrap p10l">
# <div class="t-nowrap"><span class="t-default t-small" data-trim='{"lines":2,"text":""}'>VeriPark Gulf </span></div>
# <div class="t-mute t-small">Cairo · Egypt</div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# We enable financial institutions to become digital leaders. As a professional team of global scale, we work with best clients for…</div>
# <div class="jb-tags m10t">
# <dl class="dlist is-spaced t-small m0y row">
# <dt class="p0 m20r jb-label-salary"><i class="icon is-salary m5r"></i> $1,500 - $2,000</dt>
# <dt class="p0 m20r jb-label-remote"><i class="icon is-home m5r"></i> Remote</dt>
# </dl>
# </div>
# <div class="jb-footer row is-m v-align-center m10t">
# <div class="jb-date col p0x p0t t-mute">
# <span class="p0x t-small m10r t-bold t-mute" data-automation-id="job-active-date" data-automation-jobactivedate="1728308671" data-automation-ty="1" id="jb-date-5199788">
# 30+ days ago </span>
# </div>
# <div class="jb-easy-apply col p0x p0t t-right">
# <a class="btn is-small" data-js-skip="" href="/en/register-j/applicant-register/?jb_id=5199788&amp;from_job_search=%252Fen%252Fegypt%252Fjobs%252Fdata-science-jobs%252F&amp;BtnView=1" rel="nofollow">
# <i class="icon is-flash2 m5r"></i>Easy Apply </a>
# </div>
# </div> </li>
# <li class="has-pointer-d" data-job-id="5209500" data-js-job="">
# <div class="row is-compact is-m no-wrap">
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# <a data-automation-is_aggregated="0" data-automation-is_external="1" data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/network-security-head-5209500/">
# Network &amp; Security Head </a>
# </h2>
# <div class="col p10l t-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="5209500" data-js-jobheartstatus="" data-savelinklatter="5209500" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon is-heart-solid is-20 m0 t-danger"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# </div>
# <div class="row is-m no-wrap">
# <img alt="Job Hunting  logo" class="jb-logo b bg-inverse u-block" height="50" src="//secure.b8cdn.com/bayt/assets/jobs-cwg3nimv/images/no-logo.svg" title="Job Hunting " width="50"/>
# <div class="t-nowrap p10l">
# <div class="t-nowrap"><span class="t-default t-small" data-trim='{"lines":2,"text":""}'>Job Hunting </span></div>
# <div class="t-mute t-small">Egypt</div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# Job Summary: We are a prominent food manufacturing company based in 10th of Ramadan City, seeking an experienced Network &amp; Security…</div>
# <div class="jb-tags m10t">
# <dl class="dlist is-spaced t-small m0y row">
# <dt class="p0 m20r jb-label-careerlevel"><i class="icon is-briefcase m5r"></i> Mid Career</dt>
# </dl>
# </div>
# <div class="jb-footer row is-m v-align-center m10t">
# <div class="jb-date col p0x p0t t-mute">
# <span class="p0x t-small m10r t-bold t-mute" data-automation-id="job-active-date" data-automation-jobactivedate="1730916174" data-automation-ty="1" id="jb-date-5209500">
# 24 days ago </span>
# </div>
# <div class="jb-easy-apply col p0x p0t t-right">
# <a class="btn is-small" data-js-skip="" href="/en/register-j/applicant-register/?jb_id=5209500&amp;from_job_search=%252Fen%252Fegypt%252Fjobs%252Fdata-science-jobs%252F&amp;BtnView=1" rel="nofollow">
# <i class="icon is-flash2 m5r"></i>Easy Apply </a>
# </div>
# </div> </li>
# <li class="has-pointer-d" data-job-id="5198838" data-js-job="">
# <div class="row is-compact is-m no-wrap">
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# <a data-automation-is_aggregated="0" data-automation-is_external="0" data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/business-analytics-amp-insights-lead-eli-amp-north-africa-5198838/">
# Business Analytics &amp; Insights Lead ELI &amp; North Africa </a>
# </h2>
# <div class="col p10l t-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="5198838" data-js-jobheartstatus="" data-savelinklatter="5198838" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon is-heart-solid is-20 m0 t-danger"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# </div>
# <div class="row is-m no-wrap">
# <img alt="Pfizer - United Arab Emirates logo" class="jb-logo b bg-inverse u-block" height="50" onerror="this.onerror=null;this.src='//secure.b8cdn.com/bayt/assets/jobs-cwg3nimv/images/no-logo.svg';" src="//secure.b8cdn.com/48x48/images/logo/11/1679111_logo_1612674417_n.png" title="Pfizer - United Arab Emirates" width="50"/>
# <div class="t-nowrap p10l">
# <div class="t-nowrap"><span class="t-default t-small" data-trim='{"lines":2,"text":""}'>Pfizer - United Arab Emirates </span></div>
# <div class="t-mute t-small">Cairo · Egypt</div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# need for advanced analytics and <b>data science</b> to address business opportunities and ... leadership, including articulation of the <b>data</b> and its implications for the ...</div>
# <div class="jb-tags m10t">
# <dl class="dlist is-spaced t-small m0y row">
# <dt class="p0 m20r jb-label-careerlevel"><i class="icon is-briefcase m5r"></i> Mid Career</dt>
# </dl>
# </div>
# <div class="jb-footer row is-m v-align-center m10t">
# <div class="jb-date col p0x p0t t-mute">
# <span class="p0x t-small m10r t-bold t-mute" data-automation-id="job-active-date" data-automation-jobactivedate="1728058913" data-automation-ty="1" id="jb-date-5198838">
# 30+ days ago </span>
# </div>
# </div> </li>
# <li class="has-pointer-d" data-job-id="5205410" data-js-job="">
# <div class="row is-compact is-m no-wrap">
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# <a data-automation-is_aggregated="0" data-automation-is_external="1" data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/pharmacist-5205410/">
# Pharmacist </a>
# </h2>
# <div class="col p10l t-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="5205410" data-js-jobheartstatus="" data-savelinklatter="5205410" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon is-heart-solid is-20 m0 t-danger"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# </div>
# <div class="row is-m no-wrap">
# <img alt="Axios International Consultants logo" class="jb-logo b bg-inverse u-block" height="50" loading="lazy" onerror="this.onerror=null;this.src='//secure.b8cdn.com/bayt/assets/jobs-cwg3nimv/images/no-logo.svg';" src="//secure.b8cdn.com/48x48/images/logo/07/2126307_logo_1714566764_n.png" title="Axios International Consultants" width="50"/>
# <div class="t-nowrap p10l">
# <div class="t-nowrap"><span class="t-default t-small" data-trim='{"lines":2,"text":""}'>Axios International Consultants </span></div>
# <div class="t-mute t-small">Cairo · Egypt</div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# Position: Pharmacist Location: Egypt Position Purpose The purpose of this role is to coordinate patient applications in the Patient…</div>
# <div class="jb-footer row is-m v-align-center m10t">
# <div class="jb-date col p0x p0t t-mute">
# <span class="p0x t-small m10r t-bold t-mute" data-automation-id="job-active-date" data-automation-jobactivedate="1729686636" data-automation-ty="1" id="jb-date-5205410">
# 30+ days ago </span>
# </div>
# <div class="jb-easy-apply col p0x p0t t-right">
# <a class="btn is-small" data-js-skip="" href="/en/register-j/applicant-register/?jb_id=5205410&amp;from_job_search=%252Fen%252Fegypt%252Fjobs%252Fdata-science-jobs%252F&amp;BtnView=1" rel="nofollow">
# <i class="icon is-flash2 m5r"></i>Easy Apply </a>
# </div>
# </div> </li>
# <li class="has-pointer-d" data-job-id="72038421" data-js-job="">
# <div class="row is-compact is-m no-wrap">
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# <a data-automation-is_aggregated="1" data-automation-is_external="0" data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/data-analytics-data-science-team-lead-cairo-72038421/">
# Data Analytics - Data Science Team Lead - Cairo </a>
# </h2>
# <div class="col p10l t-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="72038421" data-js-jobheartstatus="" data-savelinklatter="72038421" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon is-heart-solid is-20 m0 t-danger"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# </div>
# <div class="row is-m no-wrap">
# <img alt="Infomineo logo" class="jb-logo b bg-inverse u-block" height="50" loading="lazy" src="//secure.b8cdn.com/bayt/assets/jobs-cwg3nimv/images/no-logo.svg" title="Infomineo" width="50"/>
# <div class="t-nowrap p10l">
# <div class="t-nowrap"><span class="t-default t-small" data-trim='{"lines":2,"text":""}'>Infomineo </span></div>
# <div class="t-mute t-small">Egypt</div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# Business Translation, Graphic Design and <b>Data</b> Analytics. Infomineo counts +250 employees ... such as Computer <b>Science</b>, Machine Learning, <b>Data Science</b>, Statistics, Applied Mathematics,...</div>
# <div class="jb-footer row is-m v-align-center m10t">
# <div class="jb-date col p0x p0t t-mute">
# <span class="p0x t-small m10r t-bold t-mute" data-automation-id="job-active-date" data-automation-jobactivedate="1732492800" data-automation-ty="2" id="jb-date-72038421">
# 6 days ago </span>
# </div>
# </div> </li>
# <li class="has-pointer-d" data-job-id="72042911" data-js-job="">
# <div class="row is-compact is-m no-wrap">
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# <a data-automation-is_aggregated="1" data-automation-is_external="0" data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/customer-success-manager-focused-on-data-science-218456-72042911/">
# Customer Success Manager – Focused on Data Science - 218456 </a>
# </h2>
# <div class="col p10l t-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="72042911" data-js-jobheartstatus="" data-savelinklatter="72042911" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon is-heart-solid is-20 m0 t-danger"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# </div>
# <div class="row is-m no-wrap">
# <img alt="Teradata logo" class="jb-logo b bg-inverse u-block" height="50" loading="lazy" src="//secure.b8cdn.com/bayt/assets/jobs-cwg3nimv/images/no-logo.svg" title="Teradata" width="50"/>
# <div class="t-nowrap p10l">
# <div class="t-nowrap"><span class="t-default t-small" data-trim='{"lines":2,"text":""}'>Teradata </span></div>
# <div class="t-mute t-small">Cairo · Egypt</div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# Customer Success Manager – Focused on <b>Data Science</b> - 218456 Job Link Copied Our ... most complete cloud analytics and <b>data</b> platform for AI. By delivering ... harmonized <b>data</b>, trusted</div>
# <div class="jb-footer row is-m v-align-center m10t">
# <div class="jb-date col p0x p0t t-mute">
# <span class="p0x t-small m10r t-bold t-mute" data-automation-id="job-active-date" data-automation-jobactivedate="1732579200" data-automation-ty="2" id="jb-date-72042911">
# 5 days ago </span>
# </div>
# </div> </li>
# <li class="has-pointer-d" data-job-id="5205289" data-js-job="">
# <div class="row is-compact is-m no-wrap">
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# <a data-automation-is_aggregated="0" data-automation-is_external="0" data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/safety-coordinator-workplace-health-and-safety-5205289/">
# Safety Coordinator, Workplace Health and Safety </a>
# </h2>
# <div class="col p10l t-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="5205289" data-js-jobheartstatus="" data-savelinklatter="5205289" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon is-heart-solid is-20 m0 t-danger"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# </div>
# <div class="row is-m no-wrap">
# <img alt="Amazon MENA logo" class="jb-logo b bg-inverse u-block" height="50" loading="lazy" onerror="this.onerror=null;this.src='//secure.b8cdn.com/bayt/assets/jobs-cwg3nimv/images/no-logo.svg';" src="//secure.b8cdn.com/48x48/images/logo/48/2012648_logo_1596027638_n.png" title="Amazon MENA" width="50"/>
# <div class="t-nowrap p10l">
# <div class="t-nowrap"><span class="t-default t-small" data-trim='{"lines":2,"text":""}'>Amazon MENA </span></div>
# <div class="t-mute t-small">Cairo · Egypt</div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# DESCRIPTION Amazon is looking for a workplace, Health and Safety (WHS) Coordinator to add to the team: Year-on-year, as we continue…</div>
# <div class="jb-footer row is-m v-align-center m10t">
# <div class="jb-date col p0x p0t t-mute">
# <span class="p0x t-small m10r t-bold t-mute" data-automation-id="job-active-date" data-automation-jobactivedate="1729674716" data-automation-ty="1" id="jb-date-5205289">
# 30+ days ago </span>
# </div>
# </div> </li>
# <li class="has-pointer-d" data-job-id="5192293" data-js-job="">
# <div class="row is-compact is-m no-wrap">
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# ...
# Mid Career	</a>
#  <span class="t-mute">(3)</span> </li>
# <li class="t-small">
# <a class="jsAjaxLoad" data-automation-count="1" data-automation-facet-id="3" data-automation-id="Management" data-close-sheet="" data-js-filter="" data-js-params='{"clickedFacet":"jb_career_level_id_original"}' href="/en/egypt/jobs/data-science-jobs/?filters%5Bjb_career_level_id_original%5D%5B%5D=3" rel="nofollow">
# Management	</a>
#  <span class="t-mute">(1)</span> </li>
# </ul>
# </div>
# </div>
# <input class="accordion-toggle" id="jb_employment_type" type="checkbox"/>
# <label class="accordion-title" for="jb_employment_type">Employment Type</label>
# <div class="accordion-animate">
# <div class="accordion-content">
# <ul class="list is-basic is-spaced is-compact t-small m0">
# <li>
# <a class="jsAjaxLoad" data-close-sheet="" data-js-filter="" href="/en/egypt/jobs/data-science-jobs/">
# All	</a>
# </li>
# <li class="t-small">
# <a class="jsAjaxLoad" data-automation-count="10" data-automation-facet-id="1" data-automation-id="Full-Time-Employee" data-close-sheet="" data-js-filter="" data-js-params='{"clickedFacet":"jb_employment_type"}' href="/en/egypt/jobs/data-science-jobs/?filters%5Bjb_employment_type%5D%5B%5D=1" rel="nofollow">
# Full Time Employee	</a>
#  <span class="t-mute">(10)</span> </li>
# </ul>
# </div>
# </div>
# <input class="accordion-toggle" id="jb_gender_int" type="checkbox"/>
# <label class="accordion-title" for="jb_gender_int">Gender</label>
# <div class="accordion-animate">
# <div class="accordion-content">
# <ul class="list is-basic is-spaced is-compact t-small m0">
# <li>
# <a class="jsAjaxLoad" data-close-sheet="" data-js-filter="" href="/en/egypt/jobs/data-science-jobs/">
# All	</a>
# </li>
# <li class="t-small">
# <a class="jsAjaxLoad" data-automation-count="300" data-automation-facet-id="0" data-automation-id="Gender-Unspecified" data-close-sheet="" data-js-filter="" data-js-params='{"clickedFacet":"jb_gender_int"}' href="/en/egypt/jobs/data-science-jobs/?filters%5Bjb_gender_int%5D%5B%5D=0" rel="nofollow">
# Gender Unspecified	</a>
#  <span class="t-mute">(300)</span> </li>
# <li class="t-small">
# <a class="jsAjaxLoad" data-automation-count="1" data-automation-facet-id="1" data-automation-id="Male-Only" data-close-sheet="" data-js-filter="" data-js-params='{"clickedFacet":"jb_gender_int"}' href="/en/egypt/jobs/data-science-jobs/?filters%5Bjb_gender_int%5D%5B%5D=1" rel="nofollow">
# Male Only	</a>
#  <span class="t-mute">(1)</span> </li>
# </ul>
# </div>
# </div>
# <input class="accordion-toggle" id="employer_company_type" type="checkbox"/>
# <label class="accordion-title" for="employer_company_type">Company Type</label>
# <div class="accordion-animate">
# <div class="accordion-content">
# <ul class="list is-basic is-spaced is-compact t-small m0">
# <li>
# <a class="jsAjaxLoad" data-close-sheet="" data-js-filter="" href="/en/egypt/jobs/data-science-jobs/">
# All	</a>
# </li>
# <li class="t-small">
# <a class="jsAjaxLoad" data-automation-count="5" data-automation-facet-id="1" data-automation-id="Employer-Private-Sector" data-close-sheet="" data-js-filter="" data-js-params='{"clickedFacet":"employer_company_type"}' href="/en/egypt/jobs/data-science-jobs/?filters%5Bemployer_company_type%5D%5B%5D=1" rel="nofollow">
# Employer (Private Sector)	</a>
#  <span class="t-mute">(5)</span> </li>
# <li class="t-small">
# <a class="jsAjaxLoad" data-automation-count="3" data-automation-facet-id="2" data-automation-id="Recruitment-Agency" data-close-sheet="" data-js-filter="" data-js-params='{"clickedFacet":"employer_company_type"}' href="/en/egypt/jobs/data-science-jobs/?filters%5Bemployer_company_type%5D%5B%5D=2" rel="nofollow">
# Recruitment Agency	</a>
#  <span class="t-mute">(3)</span> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form></div>
# </div>
# </div>
# </aside>
# </section>
# <div class="can-toggle is-m m" data-toggle-sheet="{&quot;on&quot;:{&quot;afterclose&quot;:&quot;B8.resolve(B8.ToggleSheet, '#jobAlertSheet').dispose()&quot;}}" id="jobAlertSheet">
# <div class="toggle-head">
# <a class="m" data-close-sheet="" data-sheet-focus-m="" href="javascript:;" onclick="uncheckSwtichJobAlert()"><b class="t-mute">Cancel</b></a>
# </div>
# <div class="toggle-content">
# <div class="box">
# <div class="row h-align-center">
# <div class="col is-8-d">
# <div id="modalSheetContent"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <section class="p40y-d p20y-m bg-inverse" id="clusterRelatedSearches">
# <div class="box">
# <h3 class="m40b t-center">People also search for...</h3>
# <ul class="media-list is-spaced is-divided" data-empty="Nothing available">
# <li>
# <ul class="list is-tabular of-3-d of-1-m">
# <li class="t-nowrap"><a href="/en/egypt/jobs/data-science-jobs-in-cairo/" title="data science Jobs in Cairo">data science Jobs in Cairo</a></li>
# <li class="t-nowrap"><a href="/en/egypt/jobs/data-science-jobs-in-alexandria/" title="data science Jobs in Alexandria">data science Jobs in Alexandria</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </section>
# <div class="u-none" id="tmplMsg">
# <div class="msg is-success">
# <span class="js-replace"></span>
# <div class="msg-actions">
# <a class="btn is-small is-inverse" href="/en/jobseeker/my-account/subscriptions-update/" target="_blank"> MANAGE</a>
# </div>
# <button class="msg-close" data-attach-close=""></button>
# </div>
# </div>
# <div class="u-none" id="successMsg">
# <div class="msg is-default m20b-d">
# The job is now saved to your saved jobs successfully	<div class="msg-actions">
# <a class="is-inverse" href="https://www.bayt.com/en/international/jobs/?options%5Bis_saved_jobs%5D=1">Manage</a>
# </div>
# <button class="msg-close t-inverse" data-attach-close=""></button>
# </div>
# </div>
# <div class="u-none" id="alertMsg">
# <div class="msg is-default snackbar m20b-d" data-automation-id="similarJobEnableClassicView">
# Similar jobs alert created successfully. You can manage alerts in settings.	<div class="msg-actions">
# <a class="is-inverse" href="/en/jobseeker/my-account/subscriptions-update/">MANAGE</a>
# </div>
# <button class="msg-close t-inverse" data-attach-close=""></button>
# </div>
# </div>
# <div class="u-none" id="warnMsg">
# <div class="msg is-warning">
# You have reached your limit of 15 Job Alerts. To create a new Job Alert, delete one of your existing Job Alerts first.	<div class="msg-actions">
# <a class="btn is-small is-inverse" href="/en/jobseeker/my-account/subscriptions-update/" target="_blank"> MANAGE</a>
# </div>
# <button class="msg-close" data-attach-close=""></button>
# </div>
# </div>
# <div class="u-none" id="bellDisableMsg">
# <div class="msg is-default snackbar m20b-d is-stretched">
# Similar jobs alert disabled successfully. You can manage alerts in settings.	<div class="msg-actions">
# <a class="is-inverse" href="/en/jobseeker/my-account/subscriptions-update/">MANAGE</a>
# </div>
# <button class="msg-close t-inverse" data-attach-close=""></button>
# </div>
# </div>
# <footer class="u-rel bt m0" id="footer">
# <div class="box is-large">
# <div id="pageBreadcrumbs">
# <div class="row p10y">
# <div class="col">
# <ol class="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
# <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a href="https://www.bayt.com/" itemprop="item" title="Home"><span itemprop="name">Home</span></a><meta content="1" itemprop="position"/></li><li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a href="/en/egypt/jobs/search/" itemprop="item" title="Jobs"><span itemprop="name">Jobs</span></a><meta content="2" itemprop="position"/></li><li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a href="/en/egypt/jobs/" itemprop="item" title="Egypt Jobs"><span itemprop="name">Egypt Jobs</span></a><meta content="3" itemprop="position"/></li><li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><span itemprop="name">Data Science Jobs in Egypt</span><meta content="4" itemprop="position"/></li> </ol> </div>
# </div>
# <hr/>
# </div> <div class="row p10y">
# <div class="col">
# <div class="t-large t-bold m20b">Find Jobs</div>
# <ul class="list is-basic is-cols of-6-d of-2-m t-small" id="yw1">
# <li><a class="t-default" href="https://www.bayt.com/en/uae/jobs/jobs-in-abu-dhabi/"> Jobs in Abu Dhabi</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/uae/jobs/jobs-in-dubai/"> Jobs in Dubai</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/algeria/jobs/"> Jobs in Algeria</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/bahrain/jobs/"> Jobs in Bahrain</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/egypt/jobs/"> Jobs in Egypt</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/india/jobs/"> Jobs in India</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/iraq/jobs/"> Jobs in Iraq</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/jordan/jobs/"> Jobs in Jordan</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/kuwait/jobs/"> Jobs in Kuwait</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/lebanon/jobs/"> Jobs in Lebanon</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/libya/jobs/"> Jobs in Libya</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/morocco/jobs/"> Jobs in Morocco</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/oman/jobs/"> Jobs in Oman</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/pakistan/jobs/"> Jobs in Pakistan</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/qatar/jobs/"> Jobs in Qatar</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/saudi-arabia/jobs/"> Jobs in Saudi Arabia</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/tunisia/jobs/"> Jobs in Tunisia</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/uae/jobs/"> Jobs in UAE</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/yemen/jobs/"> Jobs in Yemen</a></li>
# </ul> </div>
# </div>
# <hr/>
# <div class="row p10y is-reversed-m">
# <div class="col is-4-d">
# <div class="t-large t-bold m20b">About Bayt.com</div>
# <div class="t-small p10r">Bayt.com is the leading job site in the Middle East and North Africa, connecting job seekers with employers looking to hire. Every day, thousands of new job vacancies are listed on the award-winning platform from the region's top employers.</div>
# <div class="t-large t-bold m20y">Follow Bayt.com</div>
# <ul class="list col is-6-d is-8-m is-basic is-cols of-6 m0b" id="yw2">
# <li><a aria-label="Facebook" class="m0 icon is-18 is-facebook t-default" href="https://www.facebook.com/Baytcom"></a></li>
# <li><a aria-label="Twitter" class="m0 icon is-18 is-twitter t-default" href="https://x.com/Baytcom"></a></li>
# <li><a aria-label="LinkedIn" class="m0 icon is-18 is-linkedin t-default" href="https://www.linkedin.com/company/bayt.com"></a></li>
# <li><a aria-label="YouTube" class="m0 icon is-18 is-youtube t-default" href="https://www.youtube.com/Baytcom"></a></li>
# <li><a aria-label="Instagram" class="m0 icon is-18 is-instagram t-default" href="https://www.instagram.com/baytcom/"></a></li>
# <li><a aria-label="Pinterest" class="m0 icon is-18 is-pinterest t-default" href="https://www.pinterest.com/baytcom/"></a></li>
# </ul> </div>
# <div class="col is-2-d">
# <div class="t-large t-bold m20b">Company</div>
# <ul class="list is-basic t-small m0b" id="yw3">
# <li><a class="t-default" href="https://www.bayt.com/en/about/">About Us</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/pages/contact-us/">Contact Us</a></li>
# <li><a class="t-default" href="https://careers.bayt.com/en/job-search-results/">Careers</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/about/press/">Press Corner</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/advertise/">Advertise With Us</a></li>
# </ul> </div>
# <div class="col is-2-d">
# <div class="t-large t-bold m20b">Quick Links</div>
# <ul class="list is-basic t-small m0b" id="yw4">
# <li><a class="t-default" href="https://www.bayt.com/en/blog/">Blog</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/feedback/submit/">Help Center</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/affiliates/">Affiliate Program</a></li>
# </ul> </div>
# <div class="col is-4-d">
# <div class="t-large t-bold m20b">Get the Bayt App</div>
# <div class="u-flex">
# <a class="m5r" href="https://play.google.com/store/apps/details?id=com.bayt" target="_blank">
# <img alt="Google Play" class="img-logo is-GooglePlay" height="30.622" loading="lazy" src="..." width="106"/>
# </a>
# <a href="https://apps.apple.com/us/app/bayt-com-job-search/id510893233" target="_blank">
# <img alt="App Store" class="img-logo is-AppStore" height="30.622" loading="lazy" src="..." width="106"/>
# </a>
# </div>
# <div class="row no-wrap m20t d">
# <img alt="Bayt App QR Code" data-src="//secure.b8cdn.com/bayt/assets/b8static/svg/qr-footer.svg" height="75" loading="lazy" src="..." width="75"/>
# <div class="m5l">
# <p class="m0 t-mute t-small">Scan the QR code to get the app</p>
# <img alt="arrow pointer" data-src="//secure.b8cdn.com/bayt/assets/b8static/png/footer/arrowRight.png" height="30" loading="lazy" src="..." width="30"/>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="row">
# <div class="col is-8-d t-small">
# © <b>2024 Bayt.com
# FZ-LLC.</b> All Rights Reserved.<br/>
# <a class="t-default" href="https://www.bayt.com/en/pages/terms/">Terms of Use</a><span class="d">  ·  </span><br class="m"/><a class="t-default" href="https://www.bayt.com/en/pages/privacy-statement/">Privacy Policy</a><span class="d">  ·  </span><br class="m"/><a class="t-default" href="https://www.bayt.com/en/pages/cookie-policy/">Cookie Policy</a><span class="d">  ·  </span><br class="m"/><a class="t-default has-pointer cky-banner-element">Manage Cookies</a><span class="d">  ·  </span><br class="m"/><a class="t-default" href="https://www.bayt.com/en/pages/security-message/">Security Message</a> </div>
# <div class="col is-4-d t-right-d">
# <div class="popover-owner u-iblock" data-popover='{"trigger":"click"}'>
# <div class="btn is-secondary is-outline">English<i class="icon is-internet m0 m10l"></i></div>
# <div class="popover" data-placement="tr">
# <ul class="dropdown">
# <li><a class="t-nowrap" href="/fr/egypt/jobs/data-science-jobs/" rel="nofollow">Français</a>
# </li>
# <li class="has-divider"><a class="t-nowrap" href="/ar/egypt/jobs/data-science-jobs/">العربية</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer><noscript data-deferred-styles=""><link href="https://secure.b8cdn.com/bayt/assets/baytui-791jrceb/css/B8J.css" media="all" rel="stylesheet" type="text/css"/></noscript> <script defer="defer" id="497248758" src="https://secure.b8cdn.com/bayt/assets/job-el8ou2g3/js/JobSearchClassic.js"></script>
# <script async="async" id="3804486059" src="https://www.googletagmanager.com/gtm.js?id=GTM-NW36N4"></script>
# <script>function i(url,attrs){var script=document.createElement("script");script.src=url;for(var key in attrs){script.setAttribute(key,attrs[key]||"");}document.head.appendChild(script);}try{eval("var foo=(x)=>x+1");i("https:\/\/secure.b8cdn.com\/bayt\/assets\/baytui-791jrceb\/js\/B8com.es6.js",{"type":null,"defer":true,"id":2989524678});}catch(e){i("\/bayt\/assets\/baytui-791jrceb\/js\/B8com.js",{"type":null,"defer":true,"id":2989524678});}</script>
# <script>B8.ready(function(){BaytNavigation.ajax.defaultAjaxSetup()});if(typeof window.CustomEvent!=='function'||(window.Element&&!Element.prototype.closest)||!Element.prototype.matches||typeof Object.assign!=='function'||!Array.prototype.find||!Array.prototype.findIndex)document.write('<script src="'+(function(){"use strict";try{eval("var foo=(x)=>x+1");}catch(e){return'//secure.b8cdn.com/bayt/assets/baytui-791jrceb/js/Polyfills.js';}return'//secure.b8cdn.com/bayt/assets/baytui-791jrceb/js/Polyfills.es6.js';})()+'" defer="defer"><\/script>');var dataLayer=dataLayer||[];dataLayer.push({"pageLang":"en","pageName":null,"pageSection":"Job Seeker","pageProtected":false});dataLayer.push({"gtm.start":new Date().getTime(),"event":"gtm.js"});B8.ready(function(){try{(JobSearch.init)()}catch(err){console.error(err)};});</script>
# </body>
# </html>

# %% [markdown]
# ### Step 4: Scrape Bayt for Job Data
# Switch to a different platform and extract job data from Bayt.

# %%
# Define the Bayt URL for data science jobs
url = "https://www.bayt.com/en/egypt/jobs/data-science-jobs/"
# Send a GET request with a user-agent header to mimic a browser
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
print(soup.title.text)
# Out:
# Data Science Jobs in Egypt (2024) - Bayt.com

# %% [markdown]
# #### Step 4.1: Extract Job Titles on Bayt
# Extract and print job titles from Bayt.

# %%
# Find all job titles on the page
# <h2 class="col u-stretch t-large m0 t-nowrap-d t-trim">
# <a data-automation-is_aggregated="0" data-automation-is_external="1" data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/immdiate-hiring-for-product-managerfor-a-factory-in-egypt-5214512/">
# immdiate hiring for product managerfor a factory in Egypt </a>
# </h2>
title = soup.find_all("h2", class_="m0")
for j in title:
    print(j.text.strip())
# Out:
# Senior Presales Solution Architect " Data "
# immdiate hiring for product managerfor a factory in Egypt
# Power BI Developer
# Microsoft CRM Administrator
# Network & Security Head
# Business Analytics & Insights Lead ELI & North Africa
# Pharmacist
# Data Analytics - Data Science Team Lead - Cairo
# Customer Success Manager – Focused on Data Science - 218456
# Safety Coordinator, Workplace Health and Safety
# HCM Techno-Functional Consultant
# Business Analyst (Retail Loan Origination System)
# Data Science Manager
# Senior Data Science Engineer
# Enterprise Account Executive - MENA
# Enterprise Account Executive - Saudi/UAE/Egypt
# Accountant-OUTSOURCED OPPORTUNITY-THREE MONTHS CONTRACT
# Accountant-Outsourced Opportunity-Three Months Contract
# Senior Scientist, Computational Biotherapeutics Engineering
# DAM security Engineer

# %% [markdown]
# #### Step 4.2: Extract Job URLs on Bayt
# Extract and print the URLs for job postings on Bayt.

# %%
# Extract job URLs on Bayt
jobs_url = []
urls = soup.find_all("h2", class_="m0")
for i in urls:
    jobs_url.append("https://www.bayt.com" + i.find('a').attrs['href'])
jobs_url
# Out:
# ['https://www.bayt.com/en/egypt/jobs/senior-presales-solution-architect-quot-data-quot-5206515/',
#  'https://www.bayt.com/en/egypt/jobs/immdiate-hiring-for-product-managerfor-a-factory-in-egypt-5214512/',
#  'https://www.bayt.com/en/egypt/jobs/power-bi-developer-5201473/',
#  'https://www.bayt.com/en/egypt/jobs/microsoft-crm-administrator-5199788/',
#  'https://www.bayt.com/en/egypt/jobs/network-security-head-5209500/',
#  'https://www.bayt.com/en/egypt/jobs/business-analytics-amp-insights-lead-eli-amp-north-africa-5198838/',
#  'https://www.bayt.com/en/egypt/jobs/pharmacist-5205410/',
#  'https://www.bayt.com/en/egypt/jobs/data-analytics-data-science-team-lead-cairo-72038421/',
#  'https://www.bayt.com/en/egypt/jobs/customer-success-manager-focused-on-data-science-218456-72042911/',
#  'https://www.bayt.com/en/egypt/jobs/safety-coordinator-workplace-health-and-safety-5205289/',
#  'https://www.bayt.com/en/egypt/jobs/hcm-techno-functional-consultant-5192293/',
#  'https://www.bayt.com/en/egypt/jobs/business-analyst-retail-loan-origination-system-5131383/',
#  'https://www.bayt.com/en/egypt/jobs/data-science-manager-71400725/',
#  'https://www.bayt.com/en/egypt/jobs/senior-data-science-engineer-66105998/',
#  'https://www.bayt.com/en/egypt/jobs/enterprise-account-executive-mena-72064895/',
#  'https://www.bayt.com/en/egypt/jobs/enterprise-account-executive-saudi-uae-egypt-72062531/',
#  'https://www.bayt.com/en/egypt/jobs/accountant-outsourced-opportunity-three-months-contract-72064898/',
#  'https://www.bayt.com/en/egypt/jobs/accountant-outsourced-opportunity-three-months-contract-72061163/',
#  'https://www.bayt.com/en/egypt/jobs/senior-scientist-computational-biotherapeutics-engineering-72062434/',
#  'https://www.bayt.com/en/egypt/jobs/dam-security-engineer-72060356/']

# %% [markdown]
# ### Quizzes
# Try to find additional information from the scraped pages using the following tasks:

# %% [markdown]
# #### Quiz 1: Find the Locations of Jobs

# %%
# Find the location
location = soup.find_all("div", class_ ="t-mute t-small")
for l in location:
    print(l.text)
# Out:
# Cairo · Egypt
# Alexandria · Egypt
# Cairo · Egypt
# Cairo · Egypt
# Egypt
# Cairo · Egypt
# Cairo · Egypt
# Egypt
# Cairo · Egypt
# Cairo · Egypt
# Cairo · Egypt
# Cairo · Egypt
# Cairo · Egypt
# Cairo · Egypt
# Egypt
# Egypt
# Cairo · Egypt
# Cairo · Egypt
# Rosetta · Egypt
# Cairo · Egypt

# %% [markdown]
# #### Quiz 2: Find the Company Names of Jobs

# %%
# Find the company
company = soup.find_all("div", class_ ="t-nowrap")
for c in company:
    print(c.text)
# Out:
# GIZA Systems
# Cairo · Egypt
#
# GIZA Systems
#
# Shaheen Farouk
# Alexandria · Egypt
#
# Shaheen Farouk
#
# Flint Consulting Ltd
# Cairo · Egypt
#
# Flint Consulting Ltd
#
# VeriPark Gulf
# Cairo · Egypt
#
# VeriPark Gulf
#
# Job Hunting
# Egypt
#
# Job Hunting
#
# Pfizer - United Arab Emirates
# Cairo · Egypt
#
# Pfizer - United Arab Emirates
#
# Axios International Consultants
# Cairo · Egypt
#
# Axios International Consultants
#
# Infomineo
# Egypt
#
# Infomineo
#
# Teradata
# Cairo · Egypt
#
# Teradata
#
# Amazon MENA
# Cairo · Egypt
#
# Amazon MENA
#
# شركة البدوي للتوظيف/ Albadwy Recruitment
# Cairo · Egypt
#
# شركة البدوي للتوظيف/ Albadwy Recruitment
#
# VeriPark Gulf
# Cairo · Egypt
#
# VeriPark Gulf
#
# Sylndr
# Cairo · Egypt
#
# Sylndr
#
# Sylndr
# Cairo · Egypt
#
# Sylndr
#
# Canonical
# Egypt
#
# Canonical
#
# Canonical
# Egypt
#
# Canonical
#
# Abbott
# Cairo · Egypt
#
# Abbott
#
# Abbott
# Cairo · Egypt
#
# Abbott
#
# Pfizer Manufacturing Belgium NV
# Rosetta · Egypt
#
# Pfizer Manufacturing Belgium NV
#
# Accenture
# Cairo · Egypt
#
# Accenture

# %% [markdown]
# #### Quiz 3: Extract Job Descriptions

# %%
# job descreption
desc = soup.find_all("div", class_ ="jb-descr m10t t-small")
for d in desc:
    print(d.text)
# Out:
# Data Science Solution Arch plays a crucial role in helping businesses adopt data ... client needs and demonstrate how data science solutions can solve businessproblems. Key ...
#
# This is a full-time on-site role for an enthusiactic, active and full of energy Senior Product Manager for a small factory for producing…
#
# , dashboards, and data visualizations.• Strong understanding of data modeling, data warehousing, and ETL ... Ability to integrate various data sources and maintain data...
#
# We enable financial institutions to become digital leaders. As a professional team of global scale, we work with best clients for…
#
# Job Summary: We are a prominent food manufacturing company based in 10th of Ramadan City, seeking an experienced Network & Security…
#
# need for advanced analytics and data science to address business opportunities and ... leadership, including articulation of the data and its implications for the ...
#
# Position: Pharmacist Location: Egypt Position Purpose The purpose of this role is to coordinate patient applications in the Patient…
#
# Business Translation, Graphic Design and Data Analytics. Infomineo counts +250 employees ... such as Computer Science, Machine Learning, Data Science, Statistics, Applied Mathematics,...
#
# Customer Success Manager – Focused on Data Science - 218456 Job Link Copied Our ... most complete cloud analytics and data platform for AI. By delivering ... harmonized data, trusted
#
# DESCRIPTION Amazon is looking for a workplace, Health and Safety (WHS) Coordinator to add to the team: Year-on-year, as we continue…
#
# Assist the team proactively in various aspects of Solution Design Record all issues related to Core HR & Payroll and…
#
# We enable financial institutions to become digital leaders. As a professional team of global scale, we work with best clients for…
#
# About the role As a Data Science Manager at Sylndr, you will ... analytics, business intelligence solutions, and data engineering processes that drive strategic ... execution of data...
#
# hidden in vast amounts of data, and help us make smarter ... focus will be on applying data mining techniques, doing statistical analysis ... hands-on attitude and a data-driven...
#
# better open source from the data center to cloud and edge ... favorite platform for software engineers, data scientists and AI developers. Our ... on the cloud, in their data...
#
# better open source from the data center to cloud and edge ... favorite platform for software engineers, data scientists and AI developers. Our ... on the cloud, in their data...
#
# global healthcare leader, creating breakthrough science to improve people’s health ... future, anticipating changes in medical science and technology. Working at Abbott ...
#
# global healthcare leader, creating breakthrough science to improve people’s health ... future, anticipating changes in medical science and technology. Working at Abbott ...
#
# effective products to patients. Our science and risk-based compliant quality ... of molecular modeling workflows. Analyzes data sets to discover relationships between ...
#
# Bachelor's degree in Computer Science, Information Security, or related field ... database administration, and Knowledge of data privacy regulations are preferred Why ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the sine wave
amplitude = 1        # Amplitude (A)
frequency = 1        # Frequency in Hz (f)
phase = 0            # Phase shift (phi)
time = np.linspace(0, 2, 1000)  # Time values from 0 to 2 seconds

# Calculate sine wave
sine_wave = amplitude * np.sin(2 * np.pi * frequency * time + phase)

# Plot the sine wave
plt.figure(figsize=(10, 5))
plt.plot(time, sine_wave, label="Sine Wave")
plt.title("Sine Wave")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.legend()
plt.show()
