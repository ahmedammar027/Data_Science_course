# %% [markdown]
# ## Step 1: Import Necessary Libraries
# We begin by importing the essential libraries:
# - **pandas** for data manipulation
# - **matplotlib.pyplot** for plotting
# - **seaborn** for advanced data visualization

# %%
# Import pandas for data handling, matplotlib for plotting, and seaborn for creating advanced plots
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step 2: Load the Dataset
# Load the **employee dataset** using pandas' `read_csv()` function and check its shape to understand its size.

# %%
# Read the dataset
data=pd.read_csv('datasets\employee.csv')

# Check the number of rows and columns in the dataset
# Returns the number of rows and columns as a tuple
print(data.shape)
# Out:
# (1470, 35)
# <>:2: SyntaxWarning: invalid escape sequence '\e'
# <>:2: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_34776\3692329661.py:2: SyntaxWarning: invalid escape sequence '\e'
#   data=pd.read_csv('datasets\employee.csv')

# %% [markdown]
# ## Step 3: Explore the Dataset
# Preview the first few rows of the dataset to understand its structure and content.

# %%
# Display the first five rows of the dataset
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## Step 4: Correlation Heatmap
# We will use a **heatmap** to visualize the correlation between numerical variables.
# This helps us identify which variables have strong positive or negative correlations.

# %%
# Create a heatmap of correlations between numerical variables
# Compute the correlation matrix
correlation_matrix = data.corr(numeric_only=True)  # Compute correlation for numeric columns

# Convert to long format for Plotly visualization
corr_long = correlation_matrix.reset_index().melt(id_vars="index")

# Rename columns for better readability
corr_long.columns = ["Variable 1", "Variable 2", "Correlation"]

# Create a heatmap using Plotly
fig =sns.heatmap(
    correlation_matrix,
 
     annot=True, cmap="coolwarm", fmt=".2f", cbar=True, linewidths=0.5

)
fig.show()
# Customize the plot for better readability
# plt.title('Correlation Heatmap')  
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 18
#      11 # Create a heatmap using Plotly
#      12 fig =sns.heatmap(
#      13     correlation_matrix,
#      14
#      15      annot=True, cmap="coolwarm", fmt=".2f", cbar=True, linewidths=0.5
#      16
#      17 )
# ---> 18 fig.show()
#      19 # Customize the plot for better readability
#      20 # plt.title('Correlation Heatmap')
#      21 # plt.show()
#
# AttributeError: 'Axes' object has no attribute 'show'

# %% [markdown]
# ## Step 5: Bar Plot with an Extra Variable (Hue)
# In this plot, we will analyze **MonthlyIncome** for each **Department**, while adding **Attrition** as a third dimension (hue).
# This allows us to compare income levels across departments and see how attrition status affects them.

# %%
# Create a bar plot with Attrition as the hue (extra variable)
sns.barplot(data=data,
            x="Department",
            y="MonthlyIncome",
            hue="Department")

# Customize the plot with title and axis labels
plt.title('Monthly Income by Department and Attrition')
plt.xlabel('Department')
plt.ylabel('Monthly Income')

# Rotate x-axis labels for better readability
# Out:
# Text(0, 0.5, 'Monthly Income')
